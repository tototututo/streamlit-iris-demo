# %%
pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.2-cp313-cp313-macosx_10_13_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from scikit-learn) (2.2.5)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Downloading scipy-1.16.3-cp313-cp313-macosx_14_0_x86_64.whl.metadata (62 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.7.2-cp313-cp313-macosx_10_13_x86_64.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 1.3 MB/s  0:00:07m 1.3 MB/s eta 0:00:01
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading scipy-1.16.3-cp313-cp313-macosx_14_0_x86_64.whl (23.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 1.2 MB/s  0:00:19 eta 0:00:010:00:01
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [scikit-learn]0m 3/4 [scikit-learn]
# Successfully installed joblib-1.5.2 scikit-learn-1.7.2 scipy-1.16.3 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Завантаження набору даних Iris
iris_df = pd.read_csv("data/iris.csv")

# Перемішування набору даних
seed = 42  # Визначаємо seed для відтворюваності
iris_df = iris_df.sample(frac=1, random_state=seed)

# Вибір ознак та цільової змінної
X = iris_df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
y = iris_df['Species']

# Розділення даних на тренувальну та тестову вибірки (70% тренування і 30% тестування)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=seed, stratify=y)

# Створення екземпляра класифікатора випадкових лісів
clf = RandomForestClassifier(n_estimators=100)

# Тренування класифікатора на тренувальних даних
clf.fit(X_train, y_train)

# Прогнозування на тестовому наборі
y_pred = clf.predict(X_test)

# Обчислення точності
accuracy = accuracy_score(y_test, y_pred)
print(f"Точність: {accuracy:.2f}")
# Out:
# Точність: 0.93

# %%
X_train.iloc[0]
# Out:
# SepalLengthCm    6.1
# SepalWidthCm     2.8
# PetalLengthCm    4.0
# PetalWidthCm     1.3
# Name: 71, dtype: float64

# %%
import joblib

joblib.dump(clf, "models/rf_model.joblib")
# Out:
# ['models/rf_model.joblib']

# %%
import numpy as np

input_array = X.iloc[0].values
clf.predict(np.expand_dims(input_array, axis=0))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array(['Iris-versicolor'], dtype=object)

# %%
# alternative

input_array.reshape(-1,1).T
# Out:
# array([[6.1, 2.8, 4.7, 1.2]])
